# %% [markdown]
# ### Base code

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dicionário de faturamento
dict_faturamento = {
    'data_ref': [
        '2023-01-01', 
        '2020-02-01', 
        '2021-03-01', 
        '2022-04-01', 
        '2023-05-01',
        '2023-06-01', 
        '2020-07-01', 
        '2021-08-01', 
        '2022-09-01', 
        '2023-10-01',
        '2022-11-01', 
        '2023-12-01',
        ],
    'valor': [
        400000, 
        890000, 
        760000, 
        430000, 
        920000,
        340000, 
        800000, 
        500000, 
        200000, 
        900000,
        570000, 
        995000,
        ]
}

# %% [markdown]
# ## Tarefa 1 - Trazer a média das vendas

# %%
# Construindo um Data Frame:

df_faturamento = pd.DataFrame.from_dict(dict_faturamento)
df_faturamento
# Out:
#       data_ref   valor
# 0   2023-01-01  400000
# 1   2020-02-01  890000
# 2   2021-03-01  760000
# 3   2022-04-01  430000
# 4   2023-05-01  920000
# 5   2023-06-01  340000
# 6   2020-07-01  800000
# 7   2021-08-01  500000
# 8   2022-09-01  200000
# 9   2023-10-01  900000
# 10  2022-11-01  570000
# 11  2023-12-01  995000

# %% [markdown]
# ### Média

# %%
# Calculando média
df_faturamento.valor.mean()
# Out:
# np.float64(642083.3333333334)

# %% [markdown]
# ### Mediana

# %%
# Calculando mediana
df_faturamento.valor.median()
# Out:
# np.float64(665000.0)

# %% [markdown]
# ### Moda (aqui não há valor repetido)

# %%
# Calculando moda
df_faturamento.valor.mode()
# Out:
# 0     200000
# 1     340000
# 2     400000
# 3     430000
# 4     500000
# 5     570000
# 6     760000
# 7     800000
# 8     890000
# 9     900000
# 10    920000
# 11    995000
# Name: valor, dtype: int64

# %% [markdown]
# ## Tarefa 2 - Criar uma gráfico de barras vertical

# %%
df_faturamento.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   data_ref  12 non-null     object
#  1   valor     12 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 324.0+ bytes

# %%
# Convertendo o Dtype de objetc para Date em data_ref
df_faturamento.data_ref = pd.to_datetime(df_faturamento.data_ref)
df_faturamento.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   data_ref  12 non-null     datetime64[ns]
#  1   valor     12 non-null     int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 324.0 bytes

# %%
# Formatando e plotando gráfico vertical
df_faturamento = df_faturamento.sort_values("data_ref")
df_faturamento["ano_mes"] = df_faturamento["data_ref"].dt.to_period("M")

df_faturamento.plot.bar(x='ano_mes', y='valor')
# Out:
# <Axes: xlabel='ano_mes'>

# %% [markdown]
# ## Tarefa 3 - Criar uma gráfico de barras horizontal

# %%
df_faturamento.sort_values('valor').plot.barh(x='ano_mes', y='valor')
# Out:
# <Axes: ylabel='ano_mes'>
